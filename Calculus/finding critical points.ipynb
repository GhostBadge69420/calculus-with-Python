# %%
import sympy as sym
import numpy as np
sym.init_printing()
from IPython.display import display,Math
from sympy.abc import x,y
import math
from math import gcd
x,y = sym.symbols('x,y')
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot
x,a = sym.symbols('x,a')
from matplotlib.patches import Polygon
from matplotlib import pyplot as plt
import cmath as cm
import scipy as sp
from scipy.signal import find_peaks
import seaborn as sns

# %%
# empirical method
x = np.linspace(-5,5,1000)
fx = x**2 * np.exp(-x**2)

plt.plot(x,fx)
plt.show()

# %%
# empirical method
x = np.linspace(-5,5,1000)
fx = x**2 * np.exp(-x**2)

localmax = find_peaks(fx)

localmax
# Out:
# (array([400, 599], dtype=int64), {})

# %%
# empirical method
x = np.linspace(-5,5,1000)
fx = x**2 * np.exp(-x**2)

localmax = find_peaks(fx)[0]

localmax
# Out:
# array([400, 599], dtype=int64)

# %%
# empirical method
x = np.linspace(-5,5,1000)
fx = x**2 * np.exp(-x**2)

localmax = find_peaks(fx)[0]
localmin = find_peaks(-fx)[0]

print('The critical points are' + str(x[localmax]) + ' ' + str(x[localmin]))
# Out:
# The critical points are[-0.995996  0.995996] [-0.00500501]

# %%
# empirical method
x = np.linspace(-5,5,1001)
fx = x**2 * np.exp(-x**2)

localmax = find_peaks(fx)[0]
localmin = find_peaks(-fx)[0]

print('The critical points are' + str(x[localmax]) + ' ' + str(x[localmin]))
# Out:
# The critical points are[-1.  1.] [0.]

# %%
# empirical method
x = np.linspace(-5,5,1001)
fx = x**2 * np.exp(-x**2)

localmax = find_peaks(fx)[0]
localmin = find_peaks(-fx)[0]

print('The critical points are' + str(x[localmax]) + ' ' + str(x[localmin]))

plt.plot(x,fx)
plt.plot(x[localmax],fx[localmax],'ro')
plt.show()
# Out:
# The critical points are[-1.  1.] [0.]

# %%
# empirical method
x = np.linspace(-5,5,1001)
fx = x**2 * np.exp(-x**2)

localmax = find_peaks(fx)[0]
localmin = find_peaks(-fx)[0]

print('The critical points are' + str(x[localmax]) + ' ' + str(x[localmin]))

plt.plot(x,fx)
plt.plot(x[localmax],fx[localmax],'ro')
plt.plot(x[localmin],fx[localmin],'go')
plt.show()
# Out:
# The critical points are[-1.  1.] [0.]

# %%
# empirical method

x = np.linspace(-5,5,1001)
fx = x**2 * np.exp(-x**2)
dfx = np.diff(fx)/(x[1]-x[0])

localmax = find_peaks(fx)[0]
localmin = find_peaks(-fx)[0]

print('The critical points are' + str(x[localmax])+ ' ' + str(x[localmin]))

plt.plot(x,fx)
plt.plot(x[0:-1],dfx)

plt.plot(x[localmax],fx[localmax],'ro')
plt.plot(x[localmin],fx[localmin],'go')
plt.show()
# Out:
# The critical points are[-1.  1.] [0.]

# %%
x = sym.symbols('x')
fx = x**2 * sym.exp(-x**2)

dfx = sym.diff(fx)
critpoints = sym.solve(dfx)
dfx
# Out:
#           2          2
#      3  -x         -x
# - 2⋅x ⋅ℯ    + 2⋅x⋅ℯ

# %%
x = sym.symbols('x')
fx = x**2 * sym.exp(-x**2)

dfx = sym.diff(fx)
critpoints = sym.solve(dfx)
critpoints
# Out:
# [-1, 0, 1]

# %% [markdown]
# # Exericse
#
# Determine which values of 'a' give the function a critical value at x=1 or x=2
#
# f(x,a) = x**(2) * e **(-ax) **2
#
# a ∈ {0,.25,.5,....,2}

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2,.25)
arange
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75])

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
arange
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)
# Out:
# [0]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.707106781186548, 0.0, 0.707106781186548]

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
# Out:
# [0]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.707106781186548, 0.0, 0.707106781186548]

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))
# Out:
# [0]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.707106781186548, 0.0, 0.707106781186548]

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))

ax[0].set_ylim([0,2])
ax[1].set_ylim([-2,2])
plt.show()
# Out:
# [0]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.707106781186548, 0.0, 0.707106781186548]

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))

ax[0].set_ylim([0,2])
ax[0].set_title('Function')

ax[1].set_ylim([-2,2])
ax[1].set_title('Its derivative')

plt.show()
# Out:
# [0]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.707106781186548, 0.0, 0.707106781186548]

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))

    # test for critical points
    print(critpnts)

ax[0].set_ylim([0,2])
ax[0].set_title('Function')

ax[1].set_ylim([-2,2])
ax[1].set_title('Its derivative')

plt.show()
# Out:
# [0]
# [0]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-2.00000000000000, 0.0, 2.00000000000000]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.41421356237310, 0.0, 1.41421356237310]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.15470053837925, 0.0, 1.15470053837925]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-1.00000000000000, 0.0, 1.00000000000000]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.894427190999916, 0.0, 0.894427190999916]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.816496580927726, 0.0, 0.816496580927726]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.755928946018455, 0.0, 0.755928946018455]
# [-0.707106781186548, 0.0, 0.707106781186548]
# [-0.707106781186548, 0.0, 0.707106781186548]

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))

    # test for critical points
    if 1 in critpnts:
        display(Math('\\Rightarrow %s  \\text{ has a critical point at x=1!!!! Wohooooo!}' %sym.latex(fx)))
    elif 2 in critpnts:
        display(Math('\\Rightarrow %s  \\text{ has a critical point at x=2!!!! Wohooooo!}' %sym.latex(fx)))

    else:
        display(Math('\\quad %s \\text{ has NO critical poiunts at x=1 or x=2}' %sym.latex(fx)))



ax[0].set_ylim([0,2])
ax[0].set_title('Function')

ax[1].set_ylim([-2,2])
ax[1].set_title('Its derivative')

plt.show()
# Out:
# [0]
# $\displaystyle \quad x^{2} \text{ has NO critical poiunts at x=1 or x=2}$
# [-2.00000000000000, 0.0, 2.00000000000000]
# $\displaystyle \Rightarrow x^{2} e^{- 0.25 x^{2}}  \text{ has a critical point at x=2!!!! Wohooooo!}$
# [-1.41421356237310, 0.0, 1.41421356237310]
# $\displaystyle \quad x^{2} e^{- 0.5 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-1.15470053837925, 0.0, 1.15470053837925]
# $\displaystyle \quad x^{2} e^{- 0.75 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-1.00000000000000, 0.0, 1.00000000000000]
# $\displaystyle \Rightarrow x^{2} e^{- 1.0 x^{2}}  \text{ has a critical point at x=1!!!! Wohooooo!}$
# [-0.894427190999916, 0.0, 0.894427190999916]
# $\displaystyle \quad x^{2} e^{- 1.25 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-0.816496580927726, 0.0, 0.816496580927726]
# $\displaystyle \quad x^{2} e^{- 1.5 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-0.755928946018455, 0.0, 0.755928946018455]
# $\displaystyle \quad x^{2} e^{- 1.75 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-0.707106781186548, 0.0, 0.707106781186548]
# $\displaystyle \quad x^{2} e^{- 2.0 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    print(critpnts)

    # plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))

    # test for critical points
    if 1 in critpnts:
        display(Math('\\Rightarrow %s  \\text{ has a critical point at x=1!!!! Wohooooo!}' %sym.latex(fx)))
    elif 2 in critpnts:
        display(Math('\\Rightarrow %s  \\text{ has a critical point at x=2!!!! Wohooooo!}' %sym.latex(fx)))

    else:
        display(Math('\\quad %s \\text{ has NO critical poiunts at x=1 or x=2}' %sym.latex(fx)))



ax[0].set_ylim([0,2])
ax[0].set_title('Function')
ax[0].plot([1,1],[0,2],'--',color='gray')
ax[0].plot([2,2],[0,2],'--',color='gray')

ax[1].set_ylim([-2,2])
ax[1].set_title('Its derivative')
ax[1].plot([1,1],[0,2],'--',color='gray')
ax[1].plot([2,2],[0,2],'--',color='gray')

plt.show()
# Out:
# [0]
# $\displaystyle \quad x^{2} \text{ has NO critical poiunts at x=1 or x=2}$
# [-2.00000000000000, 0.0, 2.00000000000000]
# $\displaystyle \Rightarrow x^{2} e^{- 0.25 x^{2}}  \text{ has a critical point at x=2!!!! Wohooooo!}$
# [-1.41421356237310, 0.0, 1.41421356237310]
# $\displaystyle \quad x^{2} e^{- 0.5 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-1.15470053837925, 0.0, 1.15470053837925]
# $\displaystyle \quad x^{2} e^{- 0.75 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-1.00000000000000, 0.0, 1.00000000000000]
# $\displaystyle \Rightarrow x^{2} e^{- 1.0 x^{2}}  \text{ has a critical point at x=1!!!! Wohooooo!}$
# [-0.894427190999916, 0.0, 0.894427190999916]
# $\displaystyle \quad x^{2} e^{- 1.25 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-0.816496580927726, 0.0, 0.816496580927726]
# $\displaystyle \quad x^{2} e^{- 1.5 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-0.755928946018455, 0.0, 0.755928946018455]
# $\displaystyle \quad x^{2} e^{- 1.75 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
# [-0.707106781186548, 0.0, 0.707106781186548]
# $\displaystyle \quad x^{2} e^{- 2.0 x^{2}} \text{ has NO critical poiunts at x=1 or x=2}$
